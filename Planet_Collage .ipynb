# %%
import matplotlib.pyplot as plt 
import cv2
import numpy

# %%
image1=cv2.imread('image 1.jpg')
image2=cv2.imread('image 2.jpg')

# %%
image1.shape
# Out:
# (637, 900, 3)

# %%
image2.shape
# Out:
# (554, 985, 3)

# %%
plt.imshow(image1)

# %%
plt.imshow(image2)

# %%
planet1=image1[0:500,200:700]
planet2=image2[0:500,200:700]

# %%
planet1.shape
# Out:
# (500, 500, 3)

# %%
planet2.shape
# Out:
# (500, 500, 3)

# %%
plt.imshow(planet1)

# %%
plt.imshow(planet2)

# %%
cv2.imshow('image-1',planet1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
cv2.imshow('image-1',planet2)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
final_image=numpy.hstack((planet1,planet2))
cv2.imshow('my_planet_collage',final_image)
cv2.waitKey()
cv2.destroyAllWindows()
